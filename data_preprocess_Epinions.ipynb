# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv('data/ratings_data.txt', sep=' ', header=None)
ratings.columns = ['userId', 'itemId', 'rating']
ratings.head()
# Out:
#    userId  itemId  rating
# 0       1     100       4
# 1       1     101       5
# 2       1     102       3
# 3       1      10       3
# 4       1     103       5

# %%
user_trust = pd.read_csv('data/trust_data.txt', sep=' ', header=None)
user_trust.columns = ['dummy','sourceUserId', 'targetUserId', 'trustValue']
user_trust = user_trust.drop(columns=['dummy', 'trustValue'])

# %%
x = user_trust.query('sourceUserId == 2')['targetUserId']

# %%
ratings.query('itemId == 100')['userId']
# Out:
# 0          1
# 15098    161
# 23306    232
# 27958    267
# 35163    314
# 35586    317
# 38524    331
# 70032    581
# 75891    639
# 76448    641
# 83718    728
# 84395    735
# 97957    850
# Name: userId, dtype: int64

# %%
rating_count = ratings.groupby('userId').count()
rating_count.head()
# Out:
#         itemId  rating
# userId
# 1          234     234
# 2           62      62
# 3           21      21
# 4           38      38
# 5           39      39

# %%
unique_userId = ratings['userId'].unique()
unique_userId
# Out:
# array([    1,     2,     3, ..., 49286, 49287, 49289])

# %%
ratings_by_user = ratings.groupby('userId')
ratings_by_user.head()
# Out:
#         userId  itemId  rating
# 0            1     100       4
# 1            1     101       5
# 2            1     102       3
# 3            1      10       3
# 4            1     103       5
# 234          2     235       4
# 235          2     236       5
# 236          2     237       5
# 237          2     238       2
# 238          2     239       5
# 296          3     297       5
# 297          3     298       5
# 298          3     299       4
# 299          3     300       3
# 300          3     301       5
# 317          4     318       4
# 318          4     319       4
# 319          4     320       5
# 320          4     321       5
# 321          4     322       4
# 355          5     356       5
# 356          5     357       5
# 357          5     358       5
# 358          5     359       3
# 359          5     360       5
# 394          6     395       5
# 395          6     396       5
# 396          6     397       5
# 397          6     398       4
# ...

# %%
user_counts = {}
for index, row in ratings.iterrows():
    userid, itemid = row['userId'], row['itemId']
    if userid not in user_counts:
        user_counts[userid] = {'total_ratings':0, 'friends_count':0, 'items_rated_by_friends':0}
        print('userid: ', userid, 'itemid: ', itemid)
        friend_df = user_trust.query('sourceUserId == @userid')['targetUserId']
        
        user_counts[userid]['friends_count'] = len(friend_df)
        
        total_item_rating = ratings.query('itemId == @itemid')['userId']
        
        friend_item_rating = set(friend_df).intersection(total_item_rating)
        total_user_friend_count = len(friend_item_rating)
        
        print('count of item selected by a user also selected by friends: ', total_user_friend_count)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-cd74be3b54c3> in <module>
#       1 for index, row in ratings.iterrows():
#       2     userid, itemid = row['userId'], row['itemId']
# ----> 3     friend_df = user_trust.query('sourceUserId == @userid')['targetUserId']
#       4
#       5     total_item_rating = ratings.query('itemId == @itemid')['userId']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    2845         kwargs['level'] = kwargs.pop('level', 0) + 1
#    2846         kwargs['target'] = None
# -> 2847         res = self.eval(expr, **kwargs)
#    2848
#    2849         try:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    2960             kwargs['target'] = self
# ...
